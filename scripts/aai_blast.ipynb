# %%
import argparse
import subprocess
from Bio import SeqIO
import pandas as pd
import numpy as np
import sys
import os

# %%
'''
SEQ1 = "proteins/Streptomyces_sp._MMCC_100.proteins.faa"
SEQ2 = "proteins/Streptomyces_rubrogriseus_NBRC_15455.proteins.faa"

subprocess.run(["makeblastdb", "-in", SEQ1, "-dbtype", "prot"], check=True)
subprocess.run(["makeblastdb", "-in", SEQ2, "-dbtype", "prot"], check=True)

# =====================================================
# RUN BLASTP (Ruby blast+ behavior)
# =====================================================
if not args.quiet:
    print("Running BLASTP...")

subprocess.run([
    "blastp",
    "-db", SEQ1,
    "-query", SEQ2,
    "-max_target_seqs", "1",
    "-num_threads", str(THREADS),
    "-outfmt", "6",
    "-out", 1_vs_2.tsv
], check=True)

subprocess.run([
    "blastp",
    "-db", SEQ2,
    "-query", SEQ1,
    "-max_target_seqs", "1",
    "-num_threads", str(THREADS),
    "-outfmt", "6",
    "-out", 2_vs_1.tsv
], check=True)
'''

# %% [markdown]
# # blast can be run using subprocess.run as above or directly using ! and blast parameter as given below

# %%
# =====================================================
# PARAMETERS (same as Ruby defaults)
# =====================================================

SEQ1 = "proteins/Streptomyces_sp._MMCC_100.proteins.faa"
SEQ2 = "proteins/Streptomyces_rubrogriseus_NBRC_15455.proteins.faa"

MIN_ID = 20          # -i
MIN_LEN = 0          # -l
MIN_BITSCORE = 50    # -s
LEN_FRAC = 0.0       # -L
MIN_HITS = 50        # -n
THREADS = 8          # -t

# %%
# =====================================================
# MAKE BLAST DATABASES
# =====================================================
# !makeblastdb -in proteins/Streptomyces_sp._MMCC_100.proteins.faa -dbtype  prot -out Streptomyces_sp_MMCC_100_db
# !makeblastdb -in proteins/Streptomyces_rubrogriseus_NBRC_15455.proteins.faa -dbtype  prot -out Streptomyces_rubrogriseus_NBRC_15455_db
# Out:
# Building a new DB, current time: 02/18/2026 00:03:01
# New DB name:   /Users/mdumar/Desktop/md10/Journal_of_Antibiotics/AAI/Streptomyces_sp_MMCC_100_db
# New DB title:  proteins/Streptomyces_sp._MMCC_100.proteins.faa
# Sequence type: Protein
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 7620 sequences in 0.300972 seconds.
#
#
#
#
# Building a new DB, current time: 02/18/2026 00:03:01
# New DB name:   /Users/mdumar/Desktop/md10/Journal_of_Antibiotics/AAI/Streptomyces_rubrogriseus_NBRC_15455_db
# New DB title:  proteins/Streptomyces_rubrogriseus_NBRC_15455.proteins.faa
# Sequence type: Protein
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 7577 sequences in 0.291061 seconds.

# %%
# =====================================================
# RUN BLASTP (Ruby blast+ behavior)
# =====================================================
# !blastp -db Streptomyces_sp_MMCC_100_db -query  proteins/Streptomyces_sp._MMCC_100.proteins.faa \
-max_target_seqs 1 -num_threads 8 -outfmt 6  -out 1_vs_2.tsv

# !blastp -db Streptomyces_rubrogriseus_NBRC_15455_db -query  proteins/Streptomyces_sp._MMCC_100.proteins.faa \
-max_target_seqs 1 -num_threads 8 -outfmt 6  -out 2_vs_1.tsv
# Out:
# Warning: [blastp] Examining 5 or more matches is recommended
# Warning: [Query 1-24] Examining 5 or more matches is recommended
# Warning: [Query 25-50] Examining 5 or more matches is recommended
# Warning: [Query 51-77] Examining 5 or more matches is recommended
# Warning: [Query 78-113] Examining 5 or more matches is recommended
# Warning: [Query 114-145] Examining 5 or more matches is recommended
# Warning: [Query 146-173] Examining 5 or more matches is recommended
# Warning: [Query 174-204] Examining 5 or more matches is recommended
# Warning: [Query 205-233] Examining 5 or more matches is recommended
# Warning: [Query 234-259] Examining 5 or more matches is recommended
# Warning: [Query 260-289] Examining 5 or more matches is recommended
# Warning: [Query 290-322] Examining 5 or more matches is recommended
# Warning: [Query 323-352] Examining 5 or more matches is recommended
# Warning: [Query 353-381] Examining 5 or more matches is recommended
# Warning: [Query 382-408] Examining 5 or more matches is recommended
# Warning: [Query 409-435] Examining 5 or more matches is recommended
# Warning: [Query 436-463] Examining 5 or more matches is recommended
# Warning: [Query 464-497] Examining 5 or more matches is recommended
# Warning: [Query 498-531] Examining 5 or more matches is recommended
# Warning: [Query 532-570] Examining 5 or more matches is recommended
# Warning: [Query 571-593] Examining 5 or more matches is recommended
# Warning: [Query 594-620] Examining 5 or more matches is recommended
# Warning: [Query 621-654] Examining 5 or more matches is recommended
# Warning: [Query 655-685] Examining 5 or more matches is recommended
# Warning: [Query 686-713] Examining 5 or more matches is recommended
# Warning: [Query 714-737] Examining 5 or more matches is recommended
# Warning: [Query 738-760] Examining 5 or more matches is recommended
# Warning: [Query 761-780] Examining 5 or more matches is recommended
# Warning: [Query 781-802] Examining 5 or more matches is recommended
# Warning: [Query 803-836] Examining 5 or more matches is recommended
# Warning: [Query 837-870] Examining 5 or more matches is recommended
# Warning: [Query 871-910] Examining 5 or more matches is recommended
# Warning: [Query 911-956] Examining 5 or more matches is recommended
# Warning: [Query 957-1002] Examining 5 or more matches is recommended
# Warning: [Query 1003-1038] Examining 5 or more matches is recommended
# Warning: [Query 1039-1070] Examining 5 or more matches is recommended
# Warning: [Query 1071-1101] Examining 5 or more matches is recommended
# Warning: [Query 1102-1131] Examining 5 or more matches is recommended
# Warning: [Query 1132-1163] Examining 5 or more matches is recommended
# Warning: [Query 1164-1197] Examining 5 or more matches is recommended
# Warning: [Query 1198-1220] Examining 5 or more matches is recommended
# Warning: [Query 1221-1252] Examining 5 or more matches is recommended
# Warning: [Query 1253-1288] Examining 5 or more matches is recommended
# Warning: [Query 1289-1323] Examining 5 or more matches is recommended
# Warning: [Query 1324-1350] Examining 5 or more matches is recommended
# Warning: [Query 1351-1377] Examining 5 or more matches is recommended
# Warning: [Query 1378-1413] Examining 5 or more matches is recommended
# Warning: [Query 1414-1445] Examining 5 or more matches is recommended
# Warning: [Query 1446-1484] Examining 5 or more matches is recommended
# Warning: [Query 1485-1516] Examining 5 or more matches is recommended
# Warning: [Query 1517-1548] Examining 5 or more matches is recommended
# Warning: [Query 1549-1583] Examining 5 or more matches is recommended
# Warning: [Query 1584-1613] Examining 5 or more matches is recommended
# Warning: [Query 1614-1647] Examining 5 or more matches is recommended
# Warning: [Query 1648-1681] Examining 5 or more matches is recommended
# Warning: [Query 1682-1727] Examining 5 or more matches is recommended
# Warning: [Query 1728-1772] Examining 5 or more matches is recommended
# Warning: [Query 1773-1799] Examining 5 or more matches is recommended
# Warning: [Query 1800-1827] Examining 5 or more matches is recommended
# Warning: [Query 1828-1857] Examining 5 or more matches is recommended
# Warning: [Query 1858-1891] Examining 5 or more matches is recommended
# Warning: [Query 1892-1925] Examining 5 or more matches is recommended
# Warning: [Query 1926-1953] Examining 5 or more matches is recommended
# Warning: [Query 1954-1978] Examining 5 or more matches is recommended
# Warning: [Query 1979-2003] Examining 5 or more matches is recommended
# Warning: [Query 2004-2034] Examining 5 or more matches is recommended
# Warning: [Query 2035-2067] Examining 5 or more matches is recommended
# Warning: [Query 2068-2103] Examining 5 or more matches is recommended
# Warning: [Query 2104-2138] Examining 5 or more matches is recommended
# Warning: [Query 2139-2170] Examining 5 or more matches is recommended
# Warning: [Query 2171-2198] Examining 5 or more matches is recommended
# Warning: [Query 2199-2234] Examining 5 or more matches is recommended
# Warning: [Query 2235-2260] Examining 5 or more matches is recommended
# Warning: [Query 2261-2290] Examining 5 or more matches is recommended
# Warning: [Query 2291-2322] Examining 5 or more matches is recommended
# Warning: [Query 2323-2354] Examining 5 or more matches is recommended
# Warning: [Query 2355-2382] Examining 5 or more matches is recommended
# Warning: [Query 2383-2416] Examining 5 or more matches is recommended
# Warning: [Query 2417-2440] Examining 5 or more matches is recommended
# Warning: [Query 2441-2468] Examining 5 or more matches is recommended
# Warning: [Query 2469-2498] Examining 5 or more matches is recommended
# Warning: [Query 2499-2526] Examining 5 or more matches is recommended
# Warning: [Query 2527-2563] Examining 5 or more matches is recommended
# Warning: [Query 2564-2592] Examining 5 or more matches is recommended
# Warning: [Query 2593-2620] Examining 5 or more matches is recommended
# Warning: [Query 2621-2659] Examining 5 or more matches is recommended
# Warning: [Query 2660-2689] Examining 5 or more matches is recommended
# Warning: [Query 2690-2720] Examining 5 or more matches is recommended
# Warning: [Query 2721-2756] Examining 5 or more matches is recommended
# Warning: [Query 2757-2788] Examining 5 or more matches is recommended
# Warning: [Query 2789-2812] Examining 5 or more matches is recommended
# Warning: [Query 2813-2849] Examining 5 or more matches is recommended
# Warning: [Query 2850-2880] Examining 5 or more matches is recommended
# Warning: [Query 2881-2905] Examining 5 or more matches is recommended
# Warning: [Query 2906-2945] Examining 5 or more matches is recommended
# Warning: [Query 2946-2981] Examining 5 or more matches is recommended
# Warning: [Query 2982-3005] Examining 5 or more matches is recommended
# Warning: [Query 3006-3037] Examining 5 or more matches is recommended
# Warning: [Query 3038-3069] Examining 5 or more matches is recommended
# Warning: [Query 3070-3107] Examining 5 or more matches is recommended
# Warning: [Query 3108-3137] Examining 5 or more matches is recommended
# Warning: [Query 3138-3176] Examining 5 or more matches is recommended
# Warning: [Query 3177-3208] Examining 5 or more matches is recommended
# Warning: [Query 3209-3239] Examining 5 or more matches is recommended
# Warning: [Query 3240-3273] Examining 5 or more matches is recommended
# Warning: [Query 3274-3299] Examining 5 or more matches is recommended
# Warning: [Query 3300-3333] Examining 5 or more matches is recommended
# Warning: [Query 3334-3361] Examining 5 or more matches is recommended
# Warning: [Query 3362-3390] Examining 5 or more matches is recommended
# Warning: [Query 3391-3423] Examining 5 or more matches is recommended
# Warning: [Query 3424-3456] Examining 5 or more matches is recommended
# Warning: [Query 3457-3489] Examining 5 or more matches is recommended
# Warning: [Query 3490-3523] Examining 5 or more matches is recommended
# Warning: [Query 3524-3558] Examining 5 or more matches is recommended
# Warning: [Query 3559-3585] Examining 5 or more matches is recommended
# Warning: [Query 3586-3614] Examining 5 or more matches is recommended
# Warning: [Query 3615-3650] Examining 5 or more matches is recommended
# Warning: [Query 3651-3684] Examining 5 or more matches is recommended
# Warning: [Query 3685-3717] Examining 5 or more matches is recommended
# Warning: [Query 3718-3751] Examining 5 or more matches is recommended
# Warning: [Query 3752-3771] Examining 5 or more matches is recommended
# Warning: [Query 3772-3813] Examining 5 or more matches is recommended
# Warning: [Query 3814-3830] Examining 5 or more matches is recommended
# Warning: [Query 3831-3854] Examining 5 or more matches is recommended
# Warning: [Query 3855-3884] Examining 5 or more matches is recommended
# Warning: [Query 3885-3912] Examining 5 or more matches is recommended
# Warning: [Query 3913-3940] Examining 5 or more matches is recommended
# Warning: [Query 3941-3974] Examining 5 or more matches is recommended
# Warning: [Query 3975-4000] Examining 5 or more matches is recommended
# Warning: [Query 4001-4030] Examining 5 or more matches is recommended
# Warning: [Query 4031-4062] Examining 5 or more matches is recommended
# Warning: [Query 4063-4088] Examining 5 or more matches is recommended
# Warning: [Query 4089-4118] Examining 5 or more matches is recommended
# Warning: [Query 4119-4146] Examining 5 or more matches is recommended
# Warning: [Query 4147-4177] Examining 5 or more matches is recommended
# Warning: [Query 4178-4212] Examining 5 or more matches is recommended
# Warning: [Query 4213-4242] Examining 5 or more matches is recommended
# Warning: [Query 4243-4270] Examining 5 or more matches is recommended
# Warning: [Query 4271-4304] Examining 5 or more matches is recommended
# Warning: [Query 4305-4336] Examining 5 or more matches is recommended
# Warning: [Query 4337-4363] Examining 5 or more matches is recommended
# Warning: [Query 4364-4394] Examining 5 or more matches is recommended
# Warning: [Query 4395-4426] Examining 5 or more matches is recommended
# Warning: [Query 4427-4454] Examining 5 or more matches is recommended
# Warning: [Query 4455-4487] Examining 5 or more matches is recommended
# Warning: [Query 4488-4523] Examining 5 or more matches is recommended
# Warning: [Query 4524-4556] Examining 5 or more matches is recommended
# Warning: [Query 4557-4587] Examining 5 or more matches is recommended
# Warning: [Query 4588-4620] Examining 5 or more matches is recommended
# Warning: [Query 4621-4657] Examining 5 or more matches is recommended
# Warning: [Query 4658-4686] Examining 5 or more matches is recommended
# Warning: [Query 4687-4726] Examining 5 or more matches is recommended
# Warning: [Query 4727-4767] Examining 5 or more matches is recommended
# Warning: [Query 4768-4798] Examining 5 or more matches is recommended
# Warning: [Query 4799-4821] Examining 5 or more matches is recommended
# Warning: [Query 4822-4853] Examining 5 or more matches is recommended
# Warning: [Query 4854-4885] Examining 5 or more matches is recommended
# Warning: [Query 4886-4917] Examining 5 or more matches is recommended
# Warning: [Query 4918-4946] Examining 5 or more matches is recommended
# Warning: [Query 4947-4972] Examining 5 or more matches is recommended
# Warning: [Query 4973-5007] Examining 5 or more matches is recommended
# Warning: [Query 5008-5026] Examining 5 or more matches is recommended
# Warning: [Query 5027-5055] Examining 5 or more matches is recommended
# Warning: [Query 5056-5084] Examining 5 or more matches is recommended
# Warning: [Query 5085-5116] Examining 5 or more matches is recommended
# Warning: [Query 5117-5151] Examining 5 or more matches is recommended
# Warning: [Query 5152-5185] Examining 5 or more matches is recommended
# Warning: [Query 5186-5215] Examining 5 or more matches is recommended
# Warning: [Query 5216-5249] Examining 5 or more matches is recommended
# Warning: [Query 5250-5276] Examining 5 or more matches is recommended
# Warning: [Query 5277-5307] Examining 5 or more matches is recommended
# Warning: [Query 5308-5337] Examining 5 or more matches is recommended
# Warning: [Query 5338-5367] Examining 5 or more matches is recommended
# Warning: [Query 5368-5400] Examining 5 or more matches is recommended
# Warning: [Query 5401-5441] Examining 5 or more matches is recommended
# Warning: [Query 5442-5472] Examining 5 or more matches is recommended
# Warning: [Query 5473-5505] Examining 5 or more matches is recommended
# Warning: [Query 5506-5538] Examining 5 or more matches is recommended
# Warning: [Query 5539-5583] Examining 5 or more matches is recommended
# Warning: [Query 5584-5614] Examining 5 or more matches is recommended
# Warning: [Query 5615-5655] Examining 5 or more matches is recommended
# Warning: [Query 5656-5690] Examining 5 or more matches is recommended
# Warning: [Query 5691-5721] Examining 5 or more matches is recommended
# Warning: [Query 5722-5748] Examining 5 or more matches is recommended
# Warning: [Query 5749-5797] Examining 5 or more matches is recommended
# Warning: [Query 5798-5830] Examining 5 or more matches is recommended
# Warning: [Query 5831-5862] Examining 5 or more matches is recommended
# Warning: [Query 5863-5890] Examining 5 or more matches is recommended
# Warning: [Query 5891-5923] Examining 5 or more matches is recommended
# Warning: [Query 5924-5959] Examining 5 or more matches is recommended
# Warning: [Query 5960-6000] Examining 5 or more matches is recommended
# Warning: [Query 6001-6029] Examining 5 or more matches is recommended
# Warning: [Query 6030-6063] Examining 5 or more matches is recommended
# Warning: [Query 6064-6088] Examining 5 or more matches is recommended
# Warning: [Query 6089-6118] Examining 5 or more matches is recommended
# Warning: [Query 6119-6148] Examining 5 or more matches is recommended
# Warning: [Query 6149-6185] Examining 5 or more matches is recommended
# Warning: [Query 6186-6222] Examining 5 or more matches is recommended
# Warning: [Query 6223-6253] Examining 5 or more matches is recommended
# Warning: [Query 6254-6286] Examining 5 or more matches is recommended
# Warning: [Query 6287-6325] Examining 5 or more matches is recommended
# Warning: [Query 6326-6358] Examining 5 or more matches is recommended
# Warning: [Query 6359-6388] Examining 5 or more matches is recommended
# Warning: [Query 6389-6424] Examining 5 or more matches is recommended
# Warning: [Query 6425-6466] Examining 5 or more matches is recommended
# Warning: [Query 6467-6491] Examining 5 or more matches is recommended
# Warning: [Query 6492-6528] Examining 5 or more matches is recommended
# Warning: [Query 6529-6559] Examining 5 or more matches is recommended
# Warning: [Query 6560-6584] Examining 5 or more matches is recommended
# Warning: [Query 6585-6610] Examining 5 or more matches is recommended
# Warning: [Query 6611-6635] Examining 5 or more matches is recommended
# Warning: [Query 6636-6661] Examining 5 or more matches is recommended
# Warning: [Query 6662-6692] Examining 5 or more matches is recommended
# Warning: [Query 6693-6725] Examining 5 or more matches is recommended
# Warning: [Query 6726-6756] Examining 5 or more matches is recommended
# Warning: [Query 6757-6786] Examining 5 or more matches is recommended
# Warning: [Query 6787-6819] Examining 5 or more matches is recommended
# Warning: [Query 6820-6851] Examining 5 or more matches is recommended
# Warning: [Query 6852-6894] Examining 5 or more matches is recommended
# Warning: [Query 6895-6931] Examining 5 or more matches is recommended
# Warning: [Query 6932-6957] Examining 5 or more matches is recommended
# Warning: [Query 6958-6991] Examining 5 or more matches is recommended
# Warning: [Query 6992-7020] Examining 5 or more matches is recommended
# Warning: [Query 7021-7051] Examining 5 or more matches is recommended
# Warning: [Query 7052-7079] Examining 5 or more matches is recommended
# Warning: [Query 7080-7115] Examining 5 or more matches is recommended
# Warning: [Query 7116-7148] Examining 5 or more matches is recommended
# Warning: [Query 7149-7179] Examining 5 or more matches is recommended
# Warning: [Query 7180-7207] Examining 5 or more matches is recommended
# Warning: [Query 7208-7242] Examining 5 or more matches is recommended
# Warning: [Query 7243-7277] Examining 5 or more matches is recommended
# Warning: [Query 7278-7311] Examining 5 or more matches is recommended
# Warning: [Query 7312-7339] Examining 5 or more matches is recommended
# Warning: [Query 7340-7374] Examining 5 or more matches is recommended
# Warning: [Query 7375-7414] Examining 5 or more matches is recommended
# Warning: [Query 7415-7448] Examining 5 or more matches is recommended
# Warning: [Query 7449-7487] Examining 5 or more matches is recommended
# Warning: [Query 7488-7525] Examining 5 or more matches is recommended
# Warning: [Query 7526-7562] Examining 5 or more matches is recommended
# Warning: [Query 7563-7620] Examining 5 or more matches is recommended
# Warning: [blastp] Examining 5 or more matches is recommended
# Warning: [Query 1-24] Examining 5 or more matches is recommended
# Warning: [Query 25-50] Examining 5 or more matches is recommended
# Warning: [Query 51-77] Examining 5 or more matches is recommended
# Warning: [Query 78-113] Examining 5 or more matches is recommended
# Warning: [Query 114-145] Examining 5 or more matches is recommended
# Warning: [Query 146-173] Examining 5 or more matches is recommended
# Warning: [Query 174-204] Examining 5 or more matches is recommended
# Warning: [Query 205-233] Examining 5 or more matches is recommended
# Warning: [Query 234-259] Examining 5 or more matches is recommended
# Warning: [Query 260-289] Examining 5 or more matches is recommended
# Warning: [Query 290-322] Examining 5 or more matches is recommended
# Warning: [Query 323-352] Examining 5 or more matches is recommended
# Warning: [Query 353-381] Examining 5 or more matches is recommended
# Warning: [Query 382-408] Examining 5 or more matches is recommended
# Warning: [Query 409-435] Examining 5 or more matches is recommended
# Warning: [Query 436-463] Examining 5 or more matches is recommended
# Warning: [Query 464-497] Examining 5 or more matches is recommended
# Warning: [Query 498-531] Examining 5 or more matches is recommended
# Warning: [Query 532-570] Examining 5 or more matches is recommended
# Warning: [Query 571-593] Examining 5 or more matches is recommended
# Warning: [Query 594-620] Examining 5 or more matches is recommended
# Warning: [Query 621-654] Examining 5 or more matches is recommended
# Warning: [Query 655-685] Examining 5 or more matches is recommended
# Warning: [Query 686-713] Examining 5 or more matches is recommended
# Warning: [Query 714-737] Examining 5 or more matches is recommended
# Warning: [Query 738-760] Examining 5 or more matches is recommended
# Warning: [Query 761-780] Examining 5 or more matches is recommended
# Warning: [Query 781-802] Examining 5 or more matches is recommended
# Warning: [Query 803-836] Examining 5 or more matches is recommended
# Warning: [Query 837-870] Examining 5 or more matches is recommended
# Warning: [Query 871-910] Examining 5 or more matches is recommended
# Warning: [Query 911-956] Examining 5 or more matches is recommended
# Warning: [Query 957-1002] Examining 5 or more matches is recommended
# Warning: [Query 1003-1038] Examining 5 or more matches is recommended
# Warning: [Query 1039-1070] Examining 5 or more matches is recommended
# Warning: [Query 1071-1101] Examining 5 or more matches is recommended
# Warning: [Query 1102-1131] Examining 5 or more matches is recommended
# Warning: [Query 1132-1163] Examining 5 or more matches is recommended
# Warning: [Query 1164-1197] Examining 5 or more matches is recommended
# Warning: [Query 1198-1220] Examining 5 or more matches is recommended
# Warning: [Query 1221-1252] Examining 5 or more matches is recommended
# Warning: [Query 1253-1288] Examining 5 or more matches is recommended
# Warning: [Query 1289-1323] Examining 5 or more matches is recommended
# Warning: [Query 1324-1350] Examining 5 or more matches is recommended
# Warning: [Query 1351-1377] Examining 5 or more matches is recommended
# Warning: [Query 1378-1413] Examining 5 or more matches is recommended
# Warning: [Query 1414-1445] Examining 5 or more matches is recommended
# Warning: [Query 1446-1484] Examining 5 or more matches is recommended
# Warning: [Query 1485-1516] Examining 5 or more matches is recommended
# Warning: [Query 1517-1548] Examining 5 or more matches is recommended
# Warning: [Query 1549-1583] Examining 5 or more matches is recommended
# Warning: [Query 1584-1613] Examining 5 or more matches is recommended
# Warning: [Query 1614-1647] Examining 5 or more matches is recommended
# Warning: [Query 1648-1681] Examining 5 or more matches is recommended
# Warning: [Query 1682-1727] Examining 5 or more matches is recommended
# Warning: [Query 1728-1772] Examining 5 or more matches is recommended
# Warning: [Query 1773-1799] Examining 5 or more matches is recommended
# Warning: [Query 1800-1827] Examining 5 or more matches is recommended
# Warning: [Query 1828-1857] Examining 5 or more matches is recommended
# Warning: [Query 1858-1891] Examining 5 or more matches is recommended
# Warning: [Query 1892-1925] Examining 5 or more matches is recommended
# Warning: [Query 1926-1953] Examining 5 or more matches is recommended
# Warning: [Query 1954-1978] Examining 5 or more matches is recommended
# Warning: [Query 1979-2003] Examining 5 or more matches is recommended
# Warning: [Query 2004-2034] Examining 5 or more matches is recommended
# Warning: [Query 2035-2067] Examining 5 or more matches is recommended
# Warning: [Query 2068-2103] Examining 5 or more matches is recommended
# Warning: [Query 2104-2138] Examining 5 or more matches is recommended
# Warning: [Query 2139-2170] Examining 5 or more matches is recommended
# Warning: [Query 2171-2198] Examining 5 or more matches is recommended
# Warning: [Query 2199-2234] Examining 5 or more matches is recommended
# Warning: [Query 2235-2260] Examining 5 or more matches is recommended
# Warning: [Query 2261-2290] Examining 5 or more matches is recommended
# Warning: [Query 2291-2322] Examining 5 or more matches is recommended
# Warning: [Query 2323-2354] Examining 5 or more matches is recommended
# Warning: [Query 2355-2382] Examining 5 or more matches is recommended
# Warning: [Query 2383-2416] Examining 5 or more matches is recommended
# Warning: [Query 2417-2440] Examining 5 or more matches is recommended
# Warning: [Query 2441-2468] Examining 5 or more matches is recommended
# Warning: [Query 2469-2498] Examining 5 or more matches is recommended
# Warning: [Query 2499-2526] Examining 5 or more matches is recommended
# Warning: [Query 2527-2563] Examining 5 or more matches is recommended
# Warning: [Query 2564-2592] Examining 5 or more matches is recommended
# Warning: [Query 2593-2620] Examining 5 or more matches is recommended
# Warning: [Query 2621-2659] Examining 5 or more matches is recommended
# Warning: [Query 2660-2689] Examining 5 or more matches is recommended
# Warning: [Query 2690-2720] Examining 5 or more matches is recommended
# Warning: [Query 2721-2756] Examining 5 or more matches is recommended
# Warning: [Query 2757-2788] Examining 5 or more matches is recommended
# Warning: [Query 2789-2812] Examining 5 or more matches is recommended
# Warning: [Query 2813-2849] Examining 5 or more matches is recommended
# Warning: [Query 2850-2880] Examining 5 or more matches is recommended
# Warning: [Query 2881-2905] Examining 5 or more matches is recommended
# Warning: [Query 2906-2945] Examining 5 or more matches is recommended
# Warning: [Query 2946-2981] Examining 5 or more matches is recommended
# Warning: [Query 2982-3005] Examining 5 or more matches is recommended
# Warning: [Query 3006-3037] Examining 5 or more matches is recommended
# Warning: [Query 3038-3069] Examining 5 or more matches is recommended
# Warning: [Query 3070-3107] Examining 5 or more matches is recommended
# Warning: [Query 3108-3137] Examining 5 or more matches is recommended
# Warning: [Query 3138-3176] Examining 5 or more matches is recommended
# Warning: [Query 3177-3208] Examining 5 or more matches is recommended
# Warning: [Query 3209-3239] Examining 5 or more matches is recommended
# Warning: [Query 3240-3273] Examining 5 or more matches is recommended
# Warning: [Query 3274-3299] Examining 5 or more matches is recommended
# Warning: [Query 3300-3333] Examining 5 or more matches is recommended
# Warning: [Query 3334-3361] Examining 5 or more matches is recommended
# Warning: [Query 3362-3390] Examining 5 or more matches is recommended
# Warning: [Query 3391-3423] Examining 5 or more matches is recommended
# Warning: [Query 3424-3456] Examining 5 or more matches is recommended
# Warning: [Query 3457-3489] Examining 5 or more matches is recommended
# Warning: [Query 3490-3523] Examining 5 or more matches is recommended
# Warning: [Query 3524-3558] Examining 5 or more matches is recommended
# Warning: [Query 3559-3585] Examining 5 or more matches is recommended
# Warning: [Query 3586-3614] Examining 5 or more matches is recommended
# Warning: [Query 3615-3650] Examining 5 or more matches is recommended
# Warning: [Query 3651-3684] Examining 5 or more matches is recommended
# Warning: [Query 3685-3717] Examining 5 or more matches is recommended
# Warning: [Query 3718-3751] Examining 5 or more matches is recommended
# Warning: [Query 3752-3771] Examining 5 or more matches is recommended
# Warning: [Query 3772-3813] Examining 5 or more matches is recommended
# Warning: [Query 3814-3830] Examining 5 or more matches is recommended
# Warning: [Query 3831-3854] Examining 5 or more matches is recommended
# Warning: [Query 3855-3884] Examining 5 or more matches is recommended
# Warning: [Query 3885-3912] Examining 5 or more matches is recommended
# Warning: [Query 3913-3940] Examining 5 or more matches is recommended
# Warning: [Query 3941-3974] Examining 5 or more matches is recommended
# Warning: [Query 3975-4000] Examining 5 or more matches is recommended
# Warning: [Query 4001-4030] Examining 5 or more matches is recommended
# Warning: [Query 4031-4062] Examining 5 or more matches is recommended
# Warning: [Query 4063-4088] Examining 5 or more matches is recommended
# Warning: [Query 4089-4118] Examining 5 or more matches is recommended
# Warning: [Query 4119-4146] Examining 5 or more matches is recommended
# Warning: [Query 4147-4177] Examining 5 or more matches is recommended
# Warning: [Query 4178-4212] Examining 5 or more matches is recommended
# Warning: [Query 4213-4242] Examining 5 or more matches is recommended
# Warning: [Query 4243-4270] Examining 5 or more matches is recommended
# Warning: [Query 4271-4304] Examining 5 or more matches is recommended
# Warning: [Query 4305-4336] Examining 5 or more matches is recommended
# Warning: [Query 4337-4363] Examining 5 or more matches is recommended
# Warning: [Query 4364-4394] Examining 5 or more matches is recommended
# Warning: [Query 4395-4426] Examining 5 or more matches is recommended
# Warning: [Query 4427-4454] Examining 5 or more matches is recommended
# Warning: [Query 4455-4487] Examining 5 or more matches is recommended
# Warning: [Query 4488-4523] Examining 5 or more matches is recommended
# Warning: [Query 4524-4556] Examining 5 or more matches is recommended
# Warning: [Query 4557-4587] Examining 5 or more matches is recommended
# Warning: [Query 4588-4620] Examining 5 or more matches is recommended
# Warning: [Query 4621-4657] Examining 5 or more matches is recommended
# Warning: [Query 4658-4686] Examining 5 or more matches is recommended
# Warning: [Query 4687-4726] Examining 5 or more matches is recommended
# Warning: [Query 4727-4767] Examining 5 or more matches is recommended
# Warning: [Query 4768-4798] Examining 5 or more matches is recommended
# Warning: [Query 4799-4821] Examining 5 or more matches is recommended
# Warning: [Query 4822-4853] Examining 5 or more matches is recommended
# Warning: [Query 4854-4885] Examining 5 or more matches is recommended
# Warning: [Query 4886-4917] Examining 5 or more matches is recommended
# Warning: [Query 4918-4946] Examining 5 or more matches is recommended
# Warning: [Query 4947-4972] Examining 5 or more matches is recommended
# Warning: [Query 4973-5007] Examining 5 or more matches is recommended
# Warning: [Query 5008-5026] Examining 5 or more matches is recommended
# Warning: [Query 5027-5055] Examining 5 or more matches is recommended
# Warning: [Query 5056-5084] Examining 5 or more matches is recommended
# Warning: [Query 5085-5116] Examining 5 or more matches is recommended
# Warning: [Query 5117-5151] Examining 5 or more matches is recommended
# Warning: [Query 5152-5185] Examining 5 or more matches is recommended
# Warning: [Query 5186-5215] Examining 5 or more matches is recommended
# Warning: [Query 5216-5249] Examining 5 or more matches is recommended
# Warning: [Query 5250-5276] Examining 5 or more matches is recommended
# Warning: [Query 5277-5307] Examining 5 or more matches is recommended
# Warning: [Query 5308-5337] Examining 5 or more matches is recommended
# Warning: [Query 5338-5367] Examining 5 or more matches is recommended
# Warning: [Query 5368-5400] Examining 5 or more matches is recommended
# Warning: [Query 5401-5441] Examining 5 or more matches is recommended
# Warning: [Query 5442-5472] Examining 5 or more matches is recommended
# Warning: [Query 5473-5505] Examining 5 or more matches is recommended
# Warning: [Query 5506-5538] Examining 5 or more matches is recommended
# Warning: [Query 5539-5583] Examining 5 or more matches is recommended
# Warning: [Query 5584-5614] Examining 5 or more matches is recommended
# Warning: [Query 5615-5655] Examining 5 or more matches is recommended
# Warning: [Query 5656-5690] Examining 5 or more matches is recommended
# Warning: [Query 5691-5721] Examining 5 or more matches is recommended
# Warning: [Query 5722-5748] Examining 5 or more matches is recommended
# Warning: [Query 5749-5797] Examining 5 or more matches is recommended
# Warning: [Query 5798-5830] Examining 5 or more matches is recommended
# Warning: [Query 5831-5862] Examining 5 or more matches is recommended
# Warning: [Query 5863-5890] Examining 5 or more matches is recommended
# Warning: [Query 5891-5923] Examining 5 or more matches is recommended
# Warning: [Query 5924-5959] Examining 5 or more matches is recommended
# Warning: [Query 5960-6000] Examining 5 or more matches is recommended
# Warning: [Query 6001-6029] Examining 5 or more matches is recommended
# Warning: [Query 6030-6063] Examining 5 or more matches is recommended
# Warning: [Query 6064-6088] Examining 5 or more matches is recommended
# Warning: [Query 6089-6118] Examining 5 or more matches is recommended
# Warning: [Query 6119-6148] Examining 5 or more matches is recommended
# Warning: [Query 6149-6185] Examining 5 or more matches is recommended
# Warning: [Query 6186-6222] Examining 5 or more matches is recommended
# Warning: [Query 6223-6253] Examining 5 or more matches is recommended
# Warning: [Query 6254-6286] Examining 5 or more matches is recommended
# Warning: [Query 6287-6325] Examining 5 or more matches is recommended
# Warning: [Query 6326-6358] Examining 5 or more matches is recommended
# Warning: [Query 6359-6388] Examining 5 or more matches is recommended
# Warning: [Query 6389-6424] Examining 5 or more matches is recommended
# Warning: [Query 6425-6466] Examining 5 or more matches is recommended
# Warning: [Query 6467-6491] Examining 5 or more matches is recommended
# Warning: [Query 6492-6528] Examining 5 or more matches is recommended
# Warning: [Query 6529-6559] Examining 5 or more matches is recommended
# Warning: [Query 6560-6584] Examining 5 or more matches is recommended
# Warning: [Query 6585-6610] Examining 5 or more matches is recommended
# Warning: [Query 6611-6635] Examining 5 or more matches is recommended
# Warning: [Query 6636-6661] Examining 5 or more matches is recommended
# Warning: [Query 6662-6692] Examining 5 or more matches is recommended
# Warning: [Query 6693-6725] Examining 5 or more matches is recommended
# Warning: [Query 6726-6756] Examining 5 or more matches is recommended
# Warning: [Query 6757-6786] Examining 5 or more matches is recommended
# Warning: [Query 6787-6819] Examining 5 or more matches is recommended
# Warning: [Query 6820-6851] Examining 5 or more matches is recommended
# Warning: [Query 6852-6894] Examining 5 or more matches is recommended
# Warning: [Query 6895-6931] Examining 5 or more matches is recommended
# Warning: [Query 6932-6957] Examining 5 or more matches is recommended
# Warning: [Query 6958-6991] Examining 5 or more matches is recommended
# Warning: [Query 6992-7020] Examining 5 or more matches is recommended
# Warning: [Query 7021-7051] Examining 5 or more matches is recommended
# Warning: [Query 7052-7079] Examining 5 or more matches is recommended
# Warning: [Query 7080-7115] Examining 5 or more matches is recommended
# Warning: [Query 7116-7148] Examining 5 or more matches is recommended
# Warning: [Query 7149-7179] Examining 5 or more matches is recommended
# Warning: [Query 7180-7207] Examining 5 or more matches is recommended
# Warning: [Query 7208-7242] Examining 5 or more matches is recommended
# Warning: [Query 7243-7277] Examining 5 or more matches is recommended
# Warning: [Query 7278-7311] Examining 5 or more matches is recommended
# Warning: [Query 7312-7339] Examining 5 or more matches is recommended
# Warning: [Query 7340-7374] Examining 5 or more matches is recommended
# Warning: [Query 7375-7414] Examining 5 or more matches is recommended
# Warning: [Query 7415-7448] Examining 5 or more matches is recommended
# Warning: [Query 7449-7487] Examining 5 or more matches is recommended
# Warning: [Query 7488-7525] Examining 5 or more matches is recommended
# Warning: [Query 7526-7562] Examining 5 or more matches is recommended
# Warning: [Query 7563-7620] Examining 5 or more matches is recommended

# %%
# =====================================================
# 3️⃣ LOAD BLAST OUTPUT
# =====================================================

cols = [
    "qseqid","sseqid","pident","length","mismatch","gapopen",
    "qstart","qend","sstart","send","evalue","bitscore"
]

df1 = pd.read_csv("1_vs_2.tsv", sep="\t", names=cols)
df2 = pd.read_csv("2_vs_1.tsv", sep="\t", names=cols)
df1.head()
# Out:
#                 qseqid               sseqid  pident  length  mismatch  \
# 0  JBGORK010000001.1_1  JBGORK010000001.1_1   100.0     437         0
# 1  JBGORK010000001.1_2  JBGORK010000001.1_2   100.0     331         0
# 2  JBGORK010000001.1_3  JBGORK010000001.1_3   100.0     406         0
# 3  JBGORK010000001.1_4  JBGORK010000001.1_4   100.0     264         0
# 4  JBGORK010000001.1_5  JBGORK010000001.1_5   100.0     461         0
#
#    gapopen  qstart  qend  sstart  send  evalue  bitscore
# 0        0       1   437       1   437     0.0     846.0
# 1        0       1   331       1   331     0.0     655.0
# 2        0       1   406       1   406     0.0     784.0
# 3        0       1   264       1   264     0.0     516.0
# 4        0       1   461       1   461     0.0     870.0

# %%
# =====================================================
# 4️⃣ LOAD PROTEIN LENGTHS
# =====================================================

lenA = {r.id: len(r.seq) for r in SeqIO.parse(SEQ1, "fasta")}
lenB = {r.id: len(r.seq) for r in SeqIO.parse(SEQ2, "fasta")}

# ---- Add minimum protein length ----
df1["len_q"] = df1["qseqid"].map(lenA)
df1["len_s"] = df1["sseqid"].map(lenB)
df1["min_len"] = np.minimum(df1["len_q"], df1["len_s"])

df2["len_q"] = df2["qseqid"].map(lenB)
df2["len_s"] = df2["sseqid"].map(lenA)
df2["min_len"] = np.minimum(df2["len_q"], df2["len_s"])

# ---- Remove invalid lengths ----
df1 = df1[df1["min_len"] > 0]
df2 = df2[df2["min_len"] > 0]

# ---- Apply length fraction filter ----
df1 = df1[(df1["length"] / df1["min_len"]) >= LEN_FRAC]
df2 = df2[(df2["length"] / df2["min_len"]) >= LEN_FRAC]
df1.head()
# Out:
#                 qseqid            sseqid  pident  length  mismatch  gapopen  \
# 0  JBGORK010000001.1_1  BEWD01000007.1_1  94.966     437        22        0
# 1  JBGORK010000001.1_2  BEWD01000007.1_2  97.281     331         9        0
# 2  JBGORK010000001.1_3  BEWD01000007.1_3  94.335     406        23        0
# 3  JBGORK010000001.1_4  BEWD01000007.1_4  86.415     265        21        2
# 4  JBGORK010000001.1_5  BEWD01000007.1_5  73.374     492        69        6
#
#    qstart  qend  sstart  send         evalue  bitscore  len_q  len_s  min_len
# 0       1   437       1   437   0.000000e+00     778.0    437    437      437
# 1       1   331       1   331   0.000000e+00     640.0    331    331      331
# 2       1   406       1   406   0.000000e+00     683.0    406    406      406
# 3       1   264       1   251  8.240000e-132     370.0    264    251      251
# 4       1   461       1   461   0.000000e+00     561.0    461    461      461

# %%
# ---- Keep FIRST hit per query (Ruby qry_seen logic) ----
df1 = df1.drop_duplicates("qseqid")
df2 = df2.drop_duplicates("qseqid")

# %%
# ---- Apply identity / length / bitscore filters ----
df1 = df1[
    (df1["pident"] >= MIN_ID) &
    (df1["length"] >= MIN_LEN) &
    (df1["bitscore"] >= MIN_BITSCORE)
].copy()

df2 = df2[
    (df2["pident"] >= MIN_ID) &
    (df2["length"] >= MIN_LEN) &
    (df2["bitscore"] >= MIN_BITSCORE)
].copy()
df1.head()
# Out:
#                 qseqid            sseqid  pident  length  mismatch  gapopen  \
# 0  JBGORK010000001.1_1  BEWD01000007.1_1  94.966     437        22        0
# 1  JBGORK010000001.1_2  BEWD01000007.1_2  97.281     331         9        0
# 2  JBGORK010000001.1_3  BEWD01000007.1_3  94.335     406        23        0
# 3  JBGORK010000001.1_4  BEWD01000007.1_4  86.415     265        21        2
# 4  JBGORK010000001.1_5  BEWD01000007.1_5  73.374     492        69        6
#
#    qstart  qend  sstart  send         evalue  bitscore  len_q  len_s  min_len
# 0       1   437       1   437   0.000000e+00     778.0    437    437      437
# 1       1   331       1   331   0.000000e+00     640.0    331    331      331
# 2       1   406       1   406   0.000000e+00     683.0    406    406      406
# 3       1   264       1   251  8.240000e-132     370.0    264    251      251
# 4       1   461       1   461   0.000000e+00     561.0    461    461      461

# %%
# =====================================================
# 6️⃣ ONE-WAY AAI
# =====================================================

def compute_stats(df):
    n = len(df)
    if n == 0:
        return 0, 0, 0
    mean = df["pident"].mean()
    sd = np.sqrt((df["pident"]**2).mean() - mean**2)
    return mean, sd, n

mean1, sd1, n1 = compute_stats(df1)
mean2, sd2, n2 = compute_stats(df2)

print("\n==============================")
print("ONE-WAY AAI")
print("==============================")
print(f"Genome1 → Genome2: {mean1:.2f}%  (SD: {sd1:.2f})  n={n1}")
print(f"Genome2 → Genome1: {mean2:.2f}%  (SD: {sd2:.2f})  n={n2}")
# Out:
# ==============================
# ONE-WAY AAI
# ==============================
# Genome1 → Genome2: 85.61%  (SD: 19.56)  n=6636
# Genome2 → Genome1: 84.88%  (SD: 20.25)  n=6678

# %%
# =====================================================
# 7️⃣ RECIPROCAL BEST HITS (RBH)
# =====================================================

map1 = dict(zip(df1["qseqid"], df1["sseqid"]))
map2 = dict(zip(df2["qseqid"], df2["sseqid"]))

rbh_mask = df1.apply(
    lambda r: map2.get(r["sseqid"], None) == r["qseqid"],
    axis=1
)

rbh = df1[rbh_mask]

# %%
# =====================================================
# 8️⃣ TWO-WAY AAI
# =====================================================

n_rbh = len(rbh)

print("\n==============================")
print("TWO-WAY AAI (RBH)")
print("==============================")

if n_rbh < MIN_HITS:
    print(f"Insufficient reciprocal hits: {n_rbh}")
else:
    mean_rbh = rbh["pident"].mean()
    sd_rbh = np.sqrt((rbh["pident"]**2).mean() - mean_rbh**2)

    print(f"Two-way AAI : {mean_rbh:.2f}%")
    print(f"SD          : {sd_rbh:.2f}")
    print(f"Proteins    : {n_rbh}")
    print("==============================")
# Out:
# ==============================
# TWO-WAY AAI (RBH)
# ==============================
# Two-way AAI : 91.80%
# SD          : 10.45
# Proteins    : 5722
# ==============================
